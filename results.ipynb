# %%
from TSP_SO import many_runs
# from TSP import plot_route
import numpy as np
import matplotlib.pyplot as plt

# %%
dist_central = np.loadtxt("CustDist_WHCentral.csv", skiprows=1, delimiter=",")[:,1:]
xy_central   = np.loadtxt("CustXY_WHCentral.csv", skiprows=1, delimiter=",")[:,1:].T

dist_corner  = np.loadtxt("CustDist_WHCorner.csv", skiprows=1, delimiter=",")[:,1:]
xy_corner    = np.loadtxt("CustXY_WHCorner.csv", skiprows=1, delimiter=",")[:,1:].T

orders       = np.loadtxt("CustOrd.csv", skiprows=1, delimiter=",")[:,1]

# %% [markdown]
# # 10 costumers

# %% [markdown]
# ## 10 customers, WH central, orders file

# %%
(best_solution, best_fitness, best_evolution_CentralOrdFile), \
(_, final_fitnesses) = many_runs(
                            ind_size=10,
                            distances=dist_central,
                            orders=orders,
                            pop_size=30,
                            elitist_cross=3, 
                            elitist_size = 30//5,
                            CXPB = 1,
                            MUTPB = 0.2,
                            INVPB=0.3,
                            n_runs=30)

print(f"Best fitness out of 30 runs: {best_fitness}")
print(f"Mean fitness out of 30 runs: {np.mean(final_fitnesses)}")
print(f"Std fitness out of 30 runs: {np.std(final_fitnesses)}")

plot_route(best_solution, xy_central.T[:11], orders[:11])
# Out:
# Best fitness out of 30 runs: 306.0
# Mean fitness out of 30 runs: 314.26666666666665
# Std fitness out of 30 runs: 7.999722217399524

# %% [markdown]
# ## 10 customers, WH central, orders 50

# %%
(best_solution, best_fitness, best_evolution_CentralOrd50), \
(_, final_fitnesses) = many_runs(
                            ind_size=10,
                            distances=dist_central,
                            orders=[0] + [50]*10,
                            pop_size=30,
                            elitist_cross=3, 
                            elitist_size = 30//5,
                            CXPB = 1,
                            MUTPB = 0.2,
                            INVPB=0.3,
                            n_runs=30)

print(f"Best fitness out of 30 runs: {best_fitness}")
print(f"Mean fitness out of 30 runs: {np.mean(final_fitnesses)}")
print(f"Std fitness out of 30 runs: {np.std(final_fitnesses)}")

plot_route(best_solution, xy_central.T[:11], orders[:11])
# Out:
# Best fitness out of 30 runs: 306.0
# Mean fitness out of 30 runs: 313.2
# Std fitness out of 30 runs: 7.09647799968407

# %% [markdown]
# ## 10 customers, WH corner, orders file

# %%
(best_solution, best_fitness, best_evolution_CornerlOrdFile), \
(_, final_fitnesses) = many_runs(
                            ind_size=10,
                            distances=dist_corner,
                            orders=orders,
                            pop_size=30,
                            elitist_cross=3, 
                            elitist_size = 30//5,
                            CXPB = 1,
                            MUTPB = 0.2,
                            INVPB=0.3,
                            n_runs=30)

print(f"Best fitness out of 30 runs: {best_fitness}")
print(f"Mean fitness out of 30 runs: {np.mean(final_fitnesses)}")
print(f"Std fitness out of 30 runs: {np.std(final_fitnesses)}")

plot_route(best_solution, xy_corner.T[:11], orders[:11])
# Out:
# /home/bs/.pyenv/versions/cint/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /home/bs/.pyenv/versions/cint/lib/python3.8/site-packages/deap/creator.py:138: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# Best fitness out of 30 runs: 342.0
# Mean fitness out of 30 runs: 342.0
# Std fitness out of 30 runs: 0.0

# %% [markdown]
# ## 10 customers, WH corner, orders 50

# %%
(best_solution, best_fitness, best_evolution_CornerOrd50), \
(_, final_fitnesses) = many_runs(
                            ind_size=10,
                            distances=dist_corner,
                            orders=[0] + [50]*10,
                            pop_size=30,
                            elitist_cross=3, 
                            elitist_size = 30//5,
                            CXPB = 1,
                            MUTPB = 0.2,
                            INVPB=0.3,
                            n_runs=30)

print(f"Best fitness out of 30 runs: {best_fitness}")
print(f"Mean fitness out of 30 runs: {np.mean(final_fitnesses)}")
print(f"Std fitness out of 30 runs: {np.std(final_fitnesses)}")

plot_route(best_solution, xy_corner.T[:11], orders[:11])
# Out:
# Best fitness out of 30 runs: 342.0
# Mean fitness out of 30 runs: 342.0
# Std fitness out of 30 runs: 0.0

# %%
fig, ax = plt.subplots(figsize=(6,4))

ax.plot(best_evolution_CentralOrdFile, label="WHCentral_OrdFile")
ax.plot(best_evolution_CentralOrd50, label="WHCentral_Ord50")
ax.plot(best_evolution_CornerlOrdFile, label="WHCorner_OrdFile")
ax.plot(best_evolution_CornerOrd50, label="WHCorner_Ord50")
ax.legend()

# %% [markdown]
# # 30 costumers

# %%
N = 30

# %% [markdown]
# ## 30 customers, WH central, orders file

# %%
(best_solution, best_fitness, best_evolution_CentralOrdFile), \
(_, final_fitnesses) = many_runs(
                            ind_size=N,
                            distances=dist_central,
                            orders=orders,
                            pop_size=30,
                            elitist_cross=3, 
                            elitist_size = 30//5,
                            CXPB = 1,
                            MUTPB = 0.2,
                            INVPB=0.3,
                            n_runs=30)

print(f"Best fitness out of 30 runs: {best_fitness}")
print(f"Mean fitness out of 30 runs: {np.mean(final_fitnesses)}")
print(f"Std fitness out of 30 runs: {np.std(final_fitnesses)}")

plot_route(best_solution, xy_central.T[:N+1], orders[:N+1], figsize=(10,10))

# %% [markdown]
# ## 30 customers, WH central, orders 50

# %%
(best_solution, best_fitness, best_evolution_CentralOrd50), \
(_, final_fitnesses) = many_runs(
                            ind_size=N,
                            distances=dist_central,
                            orders=[0] + [50]*N,
                            pop_size=30,
                            elitist_cross=3, 
                            elitist_size = 30//5,
                            CXPB = 1,
                            MUTPB = 0.2,
                            INVPB=0.3,
                            n_runs=30)

print(f"Best fitness out of 30 runs: {best_fitness}")
print(f"Mean fitness out of 30 runs: {np.mean(final_fitnesses)}")
print(f"Std fitness out of 30 runs: {np.std(final_fitnesses)}")

plot_route(best_solution, xy_central.T[:N+1], orders[:N+1])
# Out:
# Best fitness out of 30 runs: 543.0
# Mean fitness out of 30 runs: 587.3333333333334
# Std fitness out of 30 runs: 31.57249154283238

# %% [markdown]
# ## 30 customers, WH corner, orders file

# %%
(best_solution, best_fitness, best_evolution_CornerOrdFile), \
(_, final_fitnesses) = many_runs(
                            ind_size=N,
                            distances=dist_corner,
                            orders=orders,
                            pop_size=30,
                            elitist_cross=3, 
                            elitist_size = 30//5,
                            CXPB = 1,
                            MUTPB = 0.2,
                            INVPB=0.3,
                            n_runs=30)

print(f"Best fitness out of 30 runs: {best_fitness}")
print(f"Mean fitness out of 30 runs: {np.mean(final_fitnesses)}")
print(f"Std fitness out of 30 runs: {np.std(final_fitnesses)}")

plot_route(best_solution, xy_corner.T[:N+1], orders[:N+1])
# Out:
# Best fitness out of 30 runs: 631.0
# Mean fitness out of 30 runs: 688.1666666666666
# Std fitness out of 30 runs: 36.13316420624625

# %% [markdown]
# ## 30 customers, WH corner, orders 50

# %%
(best_solution, best_fitness, best_evolution_CornerOrd50), \
(_, final_fitnesses) = many_runs(
                            ind_size=N,
                            distances=dist_corner,
                            orders=[0] + [50]*N,
                            pop_size=30,
                            elitist_cross=3, 
                            elitist_size = 30//5,
                            CXPB = 1,
                            MUTPB = 0.2,
                            INVPB=0.3,
                            n_runs=30)

print(f"Best fitness out of 30 runs: {best_fitness}")
print(f"Mean fitness out of 30 runs: {np.mean(final_fitnesses)}")
print(f"Std fitness out of 30 runs: {np.std(final_fitnesses)}")

plot_route(best_solution, xy_corner.T[:N+1], orders[:N+1])
# Out:
# Best fitness out of 30 runs: 606.0
# Mean fitness out of 30 runs: 675.3333333333334
# Std fitness out of 30 runs: 40.519405501836054

# %%
fig, ax = plt.subplots(figsize=(6,4))

ax.plot(best_evolution_CentralOrdFile, label="WHCentral_OrdFile")
ax.plot(best_evolution_CentralOrd50, label="WHCentral_Ord50")
ax.plot(best_evolution_CornerlOrdFile, label="WHCorner_OrdFile")
ax.plot(best_evolution_CornerOrd50, label="WHCorner_Ord50")
ax.legend()

# %% [markdown]
# # 50 costumers

# %% [markdown]
# ## 50 customers, WH central, orders file

# %%
(best_solution, best_fitness, best_evolution_CentralOrdFile), \
(_, final_fitnesses) = many_runs(
                            ind_size=50,
                            distances=dist_central,
                            orders=orders,
                            pop_size=30,
                            elitist_cross=3, 
                            elitist_size = 30//5,
                            CXPB = 1,
                            MUTPB = 0.2,
                            INVPB=0.3,
                            n_runs=30)

print(f"Best fitness out of 30 runs: {best_fitness}")
print(f"Mean fitness out of 30 runs: {np.mean(final_fitnesses)}")
print(f"Std fitness out of 30 runs: {np.std(final_fitnesses)}")

plot_route(best_solution, xy_central.T, orders)
# Out:
# Best fitness out of 30 runs: 893.0
# Mean fitness out of 30 runs: 986.5333333333333
# Std fitness out of 30 runs: 62.36437729630238

# %% [markdown]
# ## 50 customers, WH central, orders 50

# %%
(best_solution, best_fitness, best_evolution_CentralOrd50), \
(_, final_fitnesses) = many_runs(
                            ind_size=50,
                            distances=dist_central,
                            orders=[0] + [50]*50,
                            pop_size=30,
                            elitist_cross=3, 
                            elitist_size = 30//5,
                            CXPB = 1,
                            MUTPB = 0.2,
                            INVPB=0.3,
                            n_runs=30)

print(f"Best fitness out of 30 runs: {best_fitness}")
print(f"Mean fitness out of 30 runs: {np.mean(final_fitnesses)}")
print(f"Std fitness out of 30 runs: {np.std(final_fitnesses)}")

plot_route(best_solution, xy_central.T, orders)
# Out:
# Best fitness out of 30 runs: 809.0
# Mean fitness out of 30 runs: 967.3
# Std fitness out of 30 runs: 64.61276963573067

# %% [markdown]
# ## 50 customers, WH corner, orders file

# %%
(best_solution, best_fitness, best_evolution_CornerOrdFile), \
(_, final_fitnesses) = many_runs(
                            ind_size=50,
                            distances=dist_corner,
                            orders=orders,
                            pop_size=30,
                            elitist_cross=3, 
                            elitist_size = 30//5,
                            CXPB = 1,
                            MUTPB = 0.2,
                            INVPB=0.3,
                            n_runs=30)

print(f"Best fitness out of 30 runs: {best_fitness}")
print(f"Mean fitness out of 30 runs: {np.mean(final_fitnesses)}")
print(f"Std fitness out of 30 runs: {np.std(final_fitnesses)}")

plot_route(best_solution, xy_corner.T, orders)
# Out:
# Best fitness out of 30 runs: 1082.0
# Mean fitness out of 30 runs: 1179.1
# Std fitness out of 30 runs: 60.38341383746589

# %% [markdown]
# ## 50 customers, WH corner, orders 50

# %%
(best_solution, best_fitness, best_evolution_CornerOrd50), \
(_, final_fitnesses) = many_runs(
                            ind_size=50,
                            distances=dist_corner,
                            orders=[0] + [50]*50,
                            pop_size=30,
                            elitist_cross=3, 
                            elitist_size = 30//5,
                            CXPB = 1,
                            MUTPB = 0.2,
                            INVPB=0.3,
                            n_runs=30)

print(f"Best fitness out of 30 runs: {best_fitness}")
print(f"Mean fitness out of 30 runs: {np.mean(final_fitnesses)}")
print(f"Std fitness out of 30 runs: {np.std(final_fitnesses)}")

plot_route(best_solution, xy_corner.T, orders)
# Out:
# Best fitness out of 30 runs: 1042.0
# Mean fitness out of 30 runs: 1144.4
# Std fitness out of 30 runs: 55.274828508704275

# %%
fig, ax = plt.subplots(figsize=(6,4))

ax.plot(best_evolution_CentralOrdFile, label="WHCentral_OrdFile")
ax.plot(best_evolution_CentralOrd50, label="WHCentral_Ord50")
ax.plot(best_evolution_CornerlOrdFile, label="WHCorner_OrdFile")
ax.plot(best_evolution_CornerOrd50, label="WHCorner_Ord50")
ax.legend()
